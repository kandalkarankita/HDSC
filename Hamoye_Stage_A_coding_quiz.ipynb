# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-8bd16aa4-461d-4084-9ec4-a7e04bd57993" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8bd16aa4-461d-4084-9ec4-a7e04bd57993">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving FoodBalanceSheets_E_Africa_NOFLAG.csv to FoodBalanceSheets_E_Africa_NOFLAG.csv

# %%
import pandas as pd
import io
  
df = pd.read_csv(io.BytesIO(uploaded['FoodBalanceSheets_E_Africa_NOFLAG.csv']),encoding='latin1')
#print(df)

pd.set_option('display.max_columns', None)
pd.reset_option('max_columns')

df.head()
# Out:
#    Area Code     Area  Item Code  ...     Y2016     Y2017     Y2018
# 0          4  Algeria       2501  ...  40551.00  41389.00  42228.00
# 1          4  Algeria       2501  ...      0.00      0.00      0.00
# 2          4  Algeria       2901  ...   3372.00   3341.00   3322.00
# 3          4  Algeria       2901  ...     94.72     92.82     91.83
# 4          4  Algeria       2901  ...     77.40     80.19     77.28
#
# [5 rows x 12 columns]

# %% [markdown]
# Question no. 11:

# %%
q_11 = df.groupby(df['Item']== "Animal fats").agg({'Y2014': ['sum'], 'Y2017': ['sum']})
print(q_11)
# Out:
#             Y2014       Y2017
#               sum         sum
# Item
# False  7755625.59  8106111.66
# True    209460.54   269617.53

# %% [markdown]
# Question no. 12:

# %%
q_12 = df.agg({'Y2015':['mean', 'std']})
print(q_12)
# Out:
#             Y2015
# mean   135.235966
# std   1603.403984

# %% [markdown]
# Question no. 13:

# %%
percent_missing = df['Y2016'].isnull().sum() * 100 / len(df['Y2016'])
ms = df['Y2016'].isnull().sum()
q_13 = pd.DataFrame({'Y2016': ms,'percent_missing': percent_missing},index=[1])
print(q_13)
# Out:
#    Y2016  percent_missing
# 1   1535         2.518747

# %% [markdown]
# Question no. 14:

# %%
features=list(['Element Code','Y2014','Y2015','Y2016','Y2017','Y2018'])

q_14 = df[features].corr()

q_14
# Out:
#               Element Code     Y2014     Y2015     Y2016     Y2017     Y2018
# Element Code      1.000000  0.024457  0.023889  0.023444  0.024254  0.024279
# Y2014             0.024457  1.000000  0.994647  0.996081  0.995230  0.994872
# Y2015             0.023889  0.994647  1.000000  0.995739  0.988048  0.988208
# Y2016             0.023444  0.996081  0.995739  1.000000  0.992785  0.992757
# Y2017             0.024254  0.995230  0.988048  0.992785  1.000000  0.998103
# Y2018             0.024279  0.994872  0.988208  0.992757  0.998103  1.000000

# %% [markdown]
# Question no. 15:

# %%
q_15 = df.groupby(df['Element']== "Import Quantity").agg({'Y2014': ['sum'], 'Y2015': ['sum'], 'Y2016': ['sum'],'Y2017': ['sum'], 'Y2018': ['sum']})
print(q_15)
# Out:
#               Y2014       Y2015       Y2016       Y2017       Y2018
#                 sum         sum         sum         sum         sum
# Element
# False    7690941.65  7765321.77  7825889.87  8081170.10  8266632.87
# True      274144.48   267018.46   286582.78   294559.09   287997.09

# %% [markdown]
# Question no. 16:

# %%
q_16 = df.groupby(df['Element']== "Production").agg({'Y2014': ['sum']},index=False)
print(q_16)
# Out:
#               Y2014
#                 sum
# Element
# False    6033798.38
# True     1931287.75

# %% [markdown]
# Question no. 17:

# %%
q_17 = df.groupby(df['Element']).agg({'Y2018': ['sum']})

q_17
# Out:
#                                              Y2018
#                                                sum
# Element
# Domestic supply quantity                2161192.10
# Export Quantity                          181594.80
# Fat supply quantity (g/capita/day)        10258.69
# Feed                                     233489.68
# Food                                    1303841.28
# Food supply (kcal/capita/day)            455261.00
# Food supply quantity (kg/capita/yr)       49056.85
# Import Quantity                          287997.09
# Losses                                   163902.00
# Other uses (non-food)                     91300.97
# Processing                               308429.00
# Production                              2075072.89
# Protein supply quantity (g/capita/day)    11833.56
# Residuals                                 34864.00
# Seed                                      25263.14
# Stock Variation                           20577.91
# ...

# %% [markdown]
# Question no. 18:

# %%
q_18 = df.groupby(df['Element']).agg({'Y2018': ['sum']})
q_18
# Out:
#                                              Y2018
#                                                sum
# Element
# Domestic supply quantity                2161192.10
# Export Quantity                          181594.80
# Fat supply quantity (g/capita/day)        10258.69
# Feed                                     233489.68
# Food                                    1303841.28
# Food supply (kcal/capita/day)            455261.00
# Food supply quantity (kg/capita/yr)       49056.85
# Import Quantity                          287997.09
# Losses                                   163902.00
# Other uses (non-food)                     91300.97
# Processing                               308429.00
# Production                              2075072.89
# Protein supply quantity (g/capita/day)    11833.56
# Residuals                                 34864.00
# Seed                                      25263.14
# Stock Variation                           20577.91
# ...

# %% [markdown]
# Question no. 19:

# %%
q_19 = df.loc[(df['Element'].isin(['Import Quantity'])) & (df['Area'].isin(['Algeria']))].agg({'Y2018': ['sum']})
print(q_19)
# Out:
#         Y2018
# sum  36238.29

# %% [markdown]
# Question no. 20:

# %%
q_20 = df.Area.nunique()
print(q_20)
# Out:
# 49
